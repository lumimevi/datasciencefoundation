# %% [markdown]
# # A basic histogram
#
# Create a simple histogram with the Histogram() function. Again we'll use the fertility data set to plot the distribution of female literacy around the world.

# %%
# Import Histogram, output_file, and show from bokeh.charts
from bokeh.charts import Histogram, output_notebook, show

# Import pandas as pd
import pandas as pd

# Import the fertility.csv data: data
data = pd.read_csv("fertility.csv", encoding = 'latin2')

# %%
data.head()
# Out:
#      Country Continent  female literacy  fertility  population
# 0      Chine       ASI             90.5      1.769  1324655000
# 1       Inde       ASI             50.8      2.682  1139964932
# 2        USA       NAM             99.0      2.077   304060000
# 3  Indonesie       ASI             88.8      2.132   227345082
# 4     Bresil       LAT             90.2      1.827   191971506

# %%
# Make the Histogram: p
p = Histogram(data, 'female literacy', title='Female Literacy', bins=40)

# Set axis labels
p.xaxis.axis_label = 'Female Literacy (% population)'
p.yaxis.axis_label = 'Number of Countries'


# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="040d87af-5db4-4d99-acac-7e7c1169aa90">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="89ce32f1-b410-4d9d-b3c0-7e69215ed001"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("89ce32f1-b410-4d9d-b3c0-7e69215ed001").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("89ce32f1-b410-4d9d-b3c0-7e69215ed001");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '89ce32f1-b410-4d9d-b3c0-7e69215ed001' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0563296a-1f32-4bb1-8e34-7e07bf92b825":{"roots":{"references":[{"attributes":{"data_source":{"id":"4340c501-95c0-4818-bd6e-6ba1c7159961","type":"ColumnDataSource"},"glyph":{"id":"c3cc2a44-a186-408a-adf5-aad154159be9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"12df8ca2-424b-4872-81d6-b7a975e3961f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(38.820000, 41.005000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(38.820000, 41.005000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1850000000000023],"x":["39.9125"],"y":[1.0]}},"id":"b9526f4b-32a9-46e4-b7cf-3ae7dbe6e46f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a1f7540-a86f-4d78-a15c-e62122b23dc5","type":"Rect"},{"attributes":{"data_source":{"id":"791a3bc5-1ada-4130-ab67-bfc8d9b758fe","type":"ColumnDataSource"},"glyph":{"id":"77a9e127-5842-4868-a043-9c0f371ddce7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"58546bc8-d852-4567-a69a-5aa576911af6","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"b9526f4b-32a9-46e4-b7cf-3ae7dbe6e46f","type":"ColumnDataSource"},"glyph":{"id":"1a1f7540-a86f-4d78-a15c-e62122b23dc5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"59588f93-57f9-4229-853d-858925696139","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(41.005000, 43.190000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(41.005000, 43.190000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.184999999999995],"x":["42.0975"],"y":[1.0]}},"id":"6cdb6a33-26a2-43eb-bd1f-fa3b92b516b5","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0fb0c7d4-2a3b-4265-baf7-92b77a25aa3d","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0ba4a84b-9e38-4dd1-9e76-80e20669a627","type":"Rect"},{"attributes":{"data_source":{"id":"afa15382-ae01-4062-99d9-15d1b96c62a5","type":"ColumnDataSource"},"glyph":{"id":"50b6b525-92aa-42c2-906c-9fabfc5bb0cf","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f619d1e2-c973-45c6-b2ae-0816f226275d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6cdb6a33-26a2-43eb-bd1f-fa3b92b516b5","type":"ColumnDataSource"},"glyph":{"id":"0fb0c7d4-2a3b-4265-baf7-92b77a25aa3d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0df23b44-c217-4ab5-aed4-bdf661d15444","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(43.190000, 45.375000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(43.190000, 45.375000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1850000000000023],"x":["44.2825"],"y":[1.0]}},"id":"655fb8a3-e2df-47fa-8bb0-8ed5d365e6fc","type":"ColumnDataSource"},{"attributes":{},"id":"a7fe233d-ec51-4f45-b38f-0328808aaabe","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"heig ...

# %% [markdown]
# # Generating multiple histograms at once
#
# Let's make separate histograms, each with 10 bins for each of the 6 continents.
#
# To do this with Bokeh charts we pass a column name to the the **color** parameter of the **Histogram()** function. In this case, the **'Continent'** column contains the continent abbreviation that we'll use to group the female literacy values in each of the 6 continents.

# %%
# Import Histogram, output_file, and show from bokeh.charts
from bokeh.charts import Histogram, output_notebook, show

# Import pandas as pd
import pandas as pd

# Import the fertility.csv data: data
data = pd.read_csv("fertility.csv", encoding = 'latin2')

# Make a Histogram: p
p = Histogram(data, 'female literacy', title='Female Literacy',
              color='Continent', legend='top_left', bins=10)

# Set axis labels
p.xaxis.axis_label = 'Female Literacy (% population)'
p.yaxis.axis_label = 'Number of Countries'


# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="907340a0-4e15-48fa-bccd-fe7496d4b034">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="25e249a5-b5a0-477f-9dcf-c7e806f02954"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("25e249a5-b5a0-477f-9dcf-c7e806f02954").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("25e249a5-b5a0-477f-9dcf-c7e806f02954");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '25e249a5-b5a0-477f-9dcf-c7e806f02954' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ac1fd30c-9f95-4dcb-b66a-a8e089441c19":{"roots":{"references":[{"attributes":{"data_source":{"id":"66983613-0d0b-496c-99cd-222f73a333e7","type":"ColumnDataSource"},"glyph":{"id":"92888639-374b-4028-98ed-f71a45ad83df","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bd50fb4b-8146-4a87-bfe8-9ca21a8b848c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"ab102824-7d62-4a68-8063-be174a92d392","type":"ColumnDataSource"},"glyph":{"id":"fe0b4e1e-81f7-46e2-8820-3a13f30ca2ad","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4cc3da04-97b6-46fe-b539-75ea8b01e0bf","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fe0b4e1e-81f7-46e2-8820-3a13f30ca2ad","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e8cf708-6cb6-4c81-8f8f-5eab210b1200","type":"Rect"},{"attributes":{"data_source":{"id":"a7131a3b-3527-4757-9195-4700e5e600e5","type":"ColumnDataSource"},"glyph":{"id":"6aae92f4-5683-4d7d-bb61-824670ac94fc","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6daf7538-993a-43cb-a8f8-e88017160640","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(93.580000, 96.690000]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[3.0],"label":["(93.580000, 96.690000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.1099999999999994],"x":["95.13499999999999"],"y":[1.5]}},"id":"05dd52b7-1a6d-44f5-a3ca-6bd0b9deb3ff","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(87.100000, 95.100000]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[5.0],"label":["(87.100000, 95.100000]"],"line_alpha":[1.0],"line_color":["black"],"width":[8.0],"x":["91.1"],"y":[2.5]}},"id":"85709b4b-a7c3-4389-988f-6e994e961807","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(79.100000, 87.100000]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[8.0],"label":["(79.100000, 87.100000]"],"line_alpha":[1.0],"line_color":["black"],"width":[8.0],"x":["83.1"],"y":[4.0]}},"id":"ab102824-7d62-4a68-8063-be174a92d392","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"85709b4b-a7c3-4389-988f-6e994e961807","type":"ColumnDataSource"},"glyph":{"id":"c1bcb423-0fb0-4752-bf28-fb5ffe75277e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5a301cf1-486c-456e-980d-0006b12521a7","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6aae92f4-5683-4d7d-bb61-824670ac94fc","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1bcb423-0fb0-4752-bf28-fb5ffe75277e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"fi ...

# %% [markdown]
# # A basic box plot
#
# In this exercise, you'll make a box plot of female literacy per continent by setting **values='female_literacy'** and **label='Continent'** with the **BoxPlot()** function.

# %%
# Import BoxPlot, output_notebook, and show from bokeh.charts
from bokeh.charts import BoxPlot, output_notebook, show

# Import pandas as pd
import pandas as pd

# Import the fertility.csv data: data
data = pd.read_csv("fertility.csv", encoding = 'latin2')

# Make a box plot: p
p = BoxPlot(data, values='female literacy', label='Continent',
             title='Female Literacy (grouped by Continent)',
             legend='bottom_right')

# Set the y axis label
p.yaxis.axis_label='Female literacy (% population)'

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="70e37dfd-443a-435e-8be1-b40de40cea3f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="539120d7-20a4-4d00-ae1c-7d10a0062616"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("539120d7-20a4-4d00-ae1c-7d10a0062616").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("539120d7-20a4-4d00-ae1c-7d10a0062616");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '539120d7-20a4-4d00-ae1c-7d10a0062616' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5b546d71-de18-4ab8-953c-2fb6d1d20091":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"Continent":["AF","AF","AF","AF"],"chart_index":[{"Continent":"AF"},{"Continent":"AF"},{"Continent":"AF"},{"Continent":"AF"}],"x0s":["AF:0.5","AF:0.65","AF:0.5","AF:0.65"],"x1s":["AF:0.5","AF:0.35","AF:0.5","AF:0.35"],"y0s":[15.1,15.1,79.3,95.1],"y1s":[41.1,15.1,95.1,95.1]}},"id":"703604bb-5edb-46fc-afba-68dc34119cbc","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Continent":["LAT"],"chart_index":[{"Continent":"LAT"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[4.6499999999999915],"label":[{"Continent":"LAT"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["LAT"],"y":[94.475]}},"id":"19175eec-dc8c-408d-94e0-31d6cfe64221","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"fb778e3e-d03f-411e-ae49-6ce14cf6fae2","type":"ColumnDataSource"},"glyph":{"id":"2edc054a-a068-4c31-a566-2da7434b9e55","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e2b63bab-5a36-40b3-8e2c-2d8eba8e4386","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"f608bee1-77c7-4946-976e-194ef68e7769","type":"Segment"},{"attributes":{"callback":null,"factors":["AF","ASI","EUR","LAT","NAM","OCE"]},"id":"8f86c952-c5bb-4516-866a-e728d56b1830","type":"FactorRange"},{"attributes":{"data_source":{"id":"19175eec-dc8c-408d-94e0-31d6cfe64221","type":"ColumnDataSource"},"glyph":{"id":"51aab96b-6211-46fb-aabf-bf7001c0c9fd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ab6130fc-8e98-445a-a5df-3b67a9e59b48","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"703604bb-5edb-46fc-afba-68dc34119cbc","type":"ColumnDataSource"},"glyph":{"id":"5d02c97c-6aa9-4aaf-bb20-f69dc835d180","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3758a967-73f7-41cd-b4d3-cfb8ddd90fe0","type":"GlyphRenderer"},{"attributes":{},"id":"1f4d5fc8-c496-4d20-85f5-73f02610d50c","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"Continent":["LAT","LAT","LAT","LAT"],"chart_index":[{"Continent":"LAT"},{"Continent":"LAT"},{"Continent":"LAT"},{"Continent":"LAT"}],"x0s":["LAT:0.5","LAT:0.65","LAT:0.5","LAT:0.65"],"x1s":["LAT:0.5","LAT:0.35","LAT:0.5","LAT:0.35"],"y0s":[68.92500000000001,68.92500000000001,96.8,99.8],"y1s":[85.65,68.92500000000001,99.8,99.8]}},"id":"53b164ef-b433-4ea6-8205-72f8e8f40cfb","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"775cde20-9d70-4135-84aa-859f502e1973","type":"Circle"},{"attributes":{"data_source":{"id":"5faacf13-0173-46ca-86f0-3b7d75ce4bc4","type":"ColumnDataSource"},"glyph":{"id":"e3a17d31-f5d0-4269-a9b5-c43d9b7348e2","type":"Segment"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c2156991-87bf-4cf5-8d28-262175c00037","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"e3a17d31-f5d0-4269-a9b5-c43d9b7348e2","type":"Segment"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Continent":["LAT"],"chart_index":[{"Continent":"LAT"}],"x_values":["LAT:0.5"],"y_values":{"__ndarray__":"zczMzMwsUUA=","dtype":"float64","shape":[1]}}},"id":"9b1c02ec-859b-4dfd-a790-3b6d0066fd41","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Continent":["EUR"],"chart_in ...

# %% [markdown]
# # Color different groups differently
#
# Like the **Histogram()** function, we can use the color parameter of the **BoxPlot()** function to color the box plot of each continent separately.
#
# In this exercise, you'll distinguish between the six continents by setting set the color parameter of the **BoxPlot()** function to **'Continent'**.

# %%
# Make a box plot: p
p = BoxPlot(data, values='female literacy', label='Continent', color='Continent',
             title='Female Literacy (grouped by Continent)',
             legend='bottom_right')

# Set the y axis label
p.yaxis.axis_label='Female literacy (% population)'

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4f497956-0b40-4b85-bf2d-a9081ebd3353">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="05d21746-bc1c-4b57-b844-67cca4a348e5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("05d21746-bc1c-4b57-b844-67cca4a348e5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("05d21746-bc1c-4b57-b844-67cca4a348e5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '05d21746-bc1c-4b57-b844-67cca4a348e5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aa6ac6a3-707a-4919-8e26-f099672dfda8":{"roots":{"references":[{"attributes":{"plot":{"id":"d370bf25-f979-4d2f-9757-e7aff668a207","subtype":"Chart","type":"Plot"}},"id":"12868760-1460-4afb-9c7b-836fcf495859","type":"PanTool"},{"attributes":{"plot":{"id":"d370bf25-f979-4d2f-9757-e7aff668a207","subtype":"Chart","type":"Plot"}},"id":"ffdf39b8-b795-4b75-a2b2-d7d380d2a12d","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"12868760-1460-4afb-9c7b-836fcf495859","type":"PanTool"},{"id":"8c6b10c1-2fff-4579-b98f-34486d4402a1","type":"WheelZoomTool"},{"id":"4b831231-e73e-4711-871d-7153a76d0b89","type":"BoxZoomTool"},{"id":"ffdf39b8-b795-4b75-a2b2-d7d380d2a12d","type":"SaveTool"},{"id":"31e001b4-4a58-4a46-a6bf-f061a8309e5f","type":"ResetTool"},{"id":"f76936f9-7719-4bb9-9806-982770c7db06","type":"HelpTool"}]},"id":"110b1261-7970-4c79-8e34-f901b550cafb","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"659835f7-77e3-4468-b9fb-654d7eb1557a","type":"Rect"},{"attributes":{"overlay":{"id":"8fbd5d1e-53f1-4ef5-88ec-8ba302119e13","type":"BoxAnnotation"},"plot":{"id":"d370bf25-f979-4d2f-9757-e7aff668a207","subtype":"Chart","type":"Plot"}},"id":"4b831231-e73e-4711-871d-7153a76d0b89","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"d370bf25-f979-4d2f-9757-e7aff668a207","subtype":"Chart","type":"Plot"}},"id":"8c6b10c1-2fff-4579-b98f-34486d4402a1","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"Female Literacy (grouped by Continent)"},"id":"8bff4ec2-788e-4310-89f4-2cfdfba86ac8","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9fa24181-f21b-44a4-89f3-acccbdd01042","type":"Rect"},{"attributes":{"plot":{"id":"d370bf25-f979-4d2f-9757-e7aff668a207","subtype":"Chart","type":"Plot"}},"id":"31e001b4-4a58-4a46-a6bf-f061a8309e5f","type":"ResetTool"},{"attributes":{"label":{"value":"LAT"},"renderers":[{"id":"57ce609e-1356-4bfb-9d54-1165bab5ae39","type":"GlyphRenderer"},{"id":"2d3d0a23-dd36-4ae0-9519-e906b0672d84","type":"GlyphRenderer"},{"id":"89283200-8b5b-4491-b6de-b3a41c6e3756","type":"GlyphRenderer"},{"id":"582185db-34db-4167-aa13-cfdc75644e66","type":"GlyphRenderer"}]},"id":"c3ba9427-43ec-49e9-b8d8-5123aadc84b9","type":"LegendItem"},{"attributes":{"callback":null,"end":105.63},"id":"a2671489-5af7-480c-b739-f6827e24556e","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Continent":["OCE"],"chart_index":[{"Continent":"OCE"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[9.625],"label":[{"Continent":"OCE"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["OCE"],"y":[93.8125]}},"id":"b9e8cf17-9d67-4a18-9329-9cc0422ed5f1","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"d50f20ed-5950-4c4d-a98b-39a229ce2411","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"16a9bf25-e76a-4b79-8992-1e04bc646333","type":"LinearAxis"}],"renderers":[{"id":"8fbd5d1e-53f1-4ef5-88ec-8ba302119e13","type":"BoxAnnotation"},{"id":"abee8530-efb2-48bf-a701-55ef13c2e9a0","type":"GlyphRenderer"},{"id":"ed7674e3-a530-49ad-8966-690f077ae8ef","type":"GlyphRenderer"},{"id":"673c0969-5327-42b0-8951-50b7e1923e4d","type":"GlyphRenderer"},{"id":"83e4cf15-99d7-4f82-95d6-ddd72c9dc4bd","type":"GlyphRenderer"},{"id":"bc7b0bdf-b59d-4f63-80f4-9048d3299089","type":"GlyphRenderer"},{"id":"304d6f45-acdf-4710-a9e5-e043a8771cfc","type":"GlyphRenderer"},{"id":"55133386-518d-4e6d-bb18-759cf3fd6a11","type":"GlyphRenderer"},{"id":"57ce609e-1356-4bfb-9d54-1165 ...

# %% [markdown]
# # A basic scatter plot
#
#
# The high level Scatter in bokeh.charts is similar to marker plots from bokeh.plotting, but differs in important ways.
# - For drawing different markers automatically based on groups in the data.
# - To choose colors automatically based on groups in the data.
# - You want to work directly with Pandas DataFrame.
#
# In this exercise, you'll make a simple scatter plot of female literacy on the y axis and population on x axis.

# %%
# Import Scatter, output_notebook, and show from bokeh.charts
from bokeh.charts import Scatter, output_notebook, show

# Import pandas as pd
import pandas as pd

# Import HoverTool from bokeh.models
from bokeh.models import HoverTool


# Import the fertility.csv data: data
data = pd.read_csv("fertility.csv", encoding = 'latin2')

# %%
data.head()
# Out:
#      Country Continent  female literacy  fertility  population
# 0      Chine       ASI             90.5      1.769  1324655000
# 1       Inde       ASI             50.8      2.682  1139964932
# 2        USA       NAM             99.0      2.077   304060000
# 3  Indonesie       ASI             88.8      2.132   227345082
# 4     Bresil       LAT             90.2      1.827   191971506

# %%
# Create a tooltips to hover
tooltips=[('Country','@Country')]

# Make a scatter plot: p
p = Scatter(data, x='population', y='female literacy',
            title='Female Literacy vs Population', tooltips=tooltips)

# Set the x-axis label
p.xaxis.axis_label = 'Population'

# Set the y-axis label
p.yaxis.axis_label = 'Female Literacy'

# Call the output_notebook() 
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7cd491a6-7fd8-49af-9a24-e398135e5e31">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4403db35-40e2-41e9-86d4-57c5df1f6bd4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4403db35-40e2-41e9-86d4-57c5df1f6bd4").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4403db35-40e2-41e9-86d4-57c5df1f6bd4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4403db35-40e2-41e9-86d4-57c5df1f6bd4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"959a5a69-d14e-4f33-bc2a-2b076499440b":{"roots":{"references":[{"attributes":{"plot":{"id":"6c4060cb-c11e-4df8-9f50-8b7b343c39f2","subtype":"Chart","type":"Plot"}},"id":"0c3f1221-b9b4-4dee-8193-a5e0f510c5c4","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5fdb5895-c47a-414c-9fac-d80399bcd5ca","type":"BoxAnnotation"},{"attributes":{},"id":"db046ab0-c977-42b3-a336-35e99288c412","type":"BasicTicker"},{"attributes":{"plot":{"id":"6c4060cb-c11e-4df8-9f50-8b7b343c39f2","subtype":"Chart","type":"Plot"}},"id":"d57ae20b-35f7-471b-9832-3f629d5af816","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"5fdb5895-c47a-414c-9fac-d80399bcd5ca","type":"BoxAnnotation"},"plot":{"id":"6c4060cb-c11e-4df8-9f50-8b7b343c39f2","subtype":"Chart","type":"Plot"}},"id":"83d8af1c-87da-4081-9aac-1fcdbec70b7c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"6c4060cb-c11e-4df8-9f50-8b7b343c39f2","subtype":"Chart","type":"Plot"}},"id":"462b0ff0-37b4-490f-a79c-ae93d385f085","type":"SaveTool"},{"attributes":{"plot":{"id":"6c4060cb-c11e-4df8-9f50-8b7b343c39f2","subtype":"Chart","type":"Plot"}},"id":"b5ad7db6-5ad9-4127-b921-1e8c27e597c1","type":"ResetTool"},{"attributes":{"plot":{"id":"6c4060cb-c11e-4df8-9f50-8b7b343c39f2","subtype":"Chart","type":"Plot"}},"id":"63684186-0bed-4c3d-a297-479bf3af6747","type":"HelpTool"},{"attributes":{},"id":"3e3292f9-722c-4507-8471-5a76f96dd1d3","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"978a594b-f42a-4b95-919f-39b82164cc94","type":"Circle"},{"attributes":{"data_source":{"id":"1a6f8530-5400-4a8b-810b-90bbc69992a2","type":"ColumnDataSource"},"glyph":{"id":"978a594b-f42a-4b95-919f-39b82164cc94","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4e7d2150-9d80-4899-9ba4-87c344613436","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values","Country"],"data":{"Country":["Chine","Inde","USA","Indonesie","Bresil","Pakistan","Bangladesh","Nig_ria","F_d_ration de Russie","Japan","Mexique","Philippines","Viet Nam","Germany","Egypte","Ethiopie","Turquie","Iran, R_publique islamique d'","Tha\u00b4lande","R_p. D_mocratique du Congo","France","UK","Italie","Myanmar","Afrique du Sud","South Korea","Ukraine","Espagne","Colombie","R_publique-Unie de Tanzanie","Soudan","Argentine","Kenya","Pologne","Alg_rie","Canada","Ouganda","Maroc","Iraq","Afghanistan","P_rou","N_pal","Venezuela","Ouzb_kistan","Malaisie","Arabie saoudite","R_p. populaire d_mocratique de Cor_e","Ghana","Y_men","Mozambique","Roumanie","C\u0165te d'Ivoire","R_publique arabe syrienne","Sri Lanka","Madagascar","Cameroun","Angola","Chili","Netherlands","Kazakhstan","Burkina Faso","Malawi","Niger","Cambodge","Guatemala","Equateur","Mali","Zambie","Zimbabwe","S_n_gal","Gr\u008fce","Cuba","Tchad","Belgium","Portugal","Czech rep","Tunisie","Hongrie","R_publique dominicaine","Guin_e","Rwanda","Bolivie","B_larus","Sweden","Azerba\u00b4djan","B_nin","Burundi","Switzerland","Bulgarie","Serbie","Honduras","Israel","Tadjikistan","Papouasie-Nouvelle-Guin_e","Togo","Jamahiriya arabe libyenne","Paraguay","R_p. d_mocratique populaire lao","El Salvador","Jordanie","Nicaragua","Sierra Leone","Denmark","Finland","Kirghizistan","Turkm_nistan","Erythr_e","Singapour","Norway","Costa Rica","Emirats arabes unis","Croatie","Ireland","R_publique centrafricaine","G_orgie","New Zealand","Liban","Lib_ria","Bosnie-Herz_govine","R_publique de Moldova","Panama","Lituanie","Uruguay","Mauritanie","Albanie","Arm_nie","Oman","Kowe\u00b ...
